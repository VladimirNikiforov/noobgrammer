# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import tensorflow as tf

# %%
classifier = tf.keras.models.Sequential()

# %%
image_size = 128
batch_size = 25

# %%
classifier.add(tf.keras.layers.Convolution2D(32, (5,5), input_shape=(image_size,image_size,3)))
classifier.add(tf.keras.layers.Activation('relu'))
classifier.add(tf.keras.layers.MaxPooling2D(pool_size = (2,2)))

classifier.add(tf.keras.layers.Convolution2D(32, (5,5)))
classifier.add(tf.keras.layers.Activation('relu'))


classifier.add(tf.keras.layers.Convolution2D(64, (3,3)))
classifier.add(tf.keras.layers.Activation('relu'))
classifier.add(tf.keras.layers.MaxPooling2D(pool_size = (2,2)))

classifier.add(tf.keras.layers.Flatten())

classifier.add(tf.keras.layers.Dense(256, activation='relu'))
classifier.add(tf.keras.layers.Dropout(0.5))
classifier.add(tf.keras.layers.Dense(1, activation='sigmoid'))

classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255, 
                                                                shear_range=0.2, 
                                                                zoom_range=0.2, 
                                                                horizontal_flip=True)
test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(r'drive/My Drive/cancer images/training_set', 
                                                 target_size=(image_size,image_size), 
                                                 batch_size=batch_size,
                                                 class_mode='binary')

test_set = test_datagen.flow_from_directory(r'drive/My Drive/cancer images/test_set', 
                                            target_size=(image_size,image_size), 
                                            batch_size=batch_size,
                                            class_mode='binary')
# Out:
# Found 2456 images belonging to 2 classes.
# Found 640 images belonging to 2 classes.

# %%
filepath = 'drive/My Drive/checkpointed_model/architecture_V2/weights-improvement-{epoch:02d}-{val_acc:.2f}.hdf5'
checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

classifier.fit_generator(training_set, 
                         steps_per_epoch = 2456//batch_size, 
                         epochs = 100, 
                         validation_data = test_set, 
                         validation_steps = 640//batch_size, 
                         callbacks=callbacks_list)
# Out:
# Epoch 1/100
# 97/98 [============================>.] - ETA: 10s - loss: 0.8529 - acc: 0.5078
# Epoch 00001: val_acc improved from -inf to 0.50080, saving model to drive/My Drive/checkpointed_model/architecture_V2/weights-improvement-01-0.50.hdf5
# 98/98 [==============================] - 1292s 13s/step - loss: 0.8511 - acc: 0.5087 - val_loss: 0.6949 - val_acc: 0.5008
# Epoch 2/100
# 97/98 [============================>.] - ETA: 2s - loss: 0.6925 - acc: 0.5335
# Epoch 00002: val_acc improved from 0.50080 to 0.50400, saving model to drive/My Drive/checkpointed_model/architecture_V2/weights-improvement-02-0.50.hdf5
# 98/98 [==============================] - 239s 2s/step - loss: 0.6925 - acc: 0.5329 - val_loss: 0.6988 - val_acc: 0.5040
# Epoch 3/100
# 97/98 [============================>.] - ETA: 2s - loss: 0.6935 - acc: 0.5376
# Epoch 00003: val_acc did not improve from 0.50400
# ...

# %%
tf.keras.models.save_model(model = classifier,
                           filepath = 'drive/My Drive/checkpointed_model/architecture_V2/end_weights-{epoch:02d}-{val_acc:.2f}.hdf5',
                           overwrite=True,
                           include_optimizer=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c074cd2e7e5c> in <module>()
# ----> 1 tf.keras.models.save_model(model = classifier,
#       2                            filepath = 'drive/My Drive/checkpointed_model/architecture_V2/end_weights-{epoch:02d}-{val_acc:.2f}.hdf5',
#       3                            overwrite=True,
#       4                            include_optimizer=True)
#
# NameError: name 'tf' is not defined
